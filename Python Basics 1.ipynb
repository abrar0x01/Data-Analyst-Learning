# %%
name= "Abrar"
age= 24
height= 175

# %%
print(name)
print(age)
print(height)
# Out:
# Abrar
# 24
# 175

# %%
print("Name:",name)
print("Age:",age)
print("Height:",height)
# Out:
# Name: Abrar
# Age: 24
# Height: 175

# %%
name= "Abrar"
age= 24
city="Ranebennur"

# %%
print("Name:",name)
print("Age:",age)
print("City:",city)
# Out:
# Name: Abrar
# Age: 24
# City: Ranebennur

# %%
age = 24
print(age)
print(type(age))
# Out:
# 24
# <class 'int'>

# %%
name = "Abrar"
age = 24
height = 175.5
student = True
print(type(name))
print(type(age))
print(type(True))
# Out:
# <class 'str'>
# <class 'int'>
# <class 'bool'>

# %%
name = input("Enter your name:")
print("Hello,",name)
# Out:
# Enter your name: Abrar
# Hello, Abrar

# %%
age = input("Enter your age:")
print(type(age))
# Out:
# Enter your age: 24
# <class 'str'>

# %%
age=int(input("Enter your age:"))
print("Next year your age will be", age+1)
# Out:
# Enter your age: 24
# Next year your age will be 25

# %%
height=float(input("Enter your height in cm:"))
print("Your height is",height,"cm")
# Out:
# Enter your height in cm: 175.5
# Your height is 175.5 cm

# %%
name = input("Enter your name:")
age = int(input("Enter your age:"))
print("Welcome", name)
print("After 5 years, your age will be ", age + 5)
# Out:
# Enter your name: Abrar
# Enter your age: 24
# Welcome Abrar
# After 5 years, your age will be  29

# %%
#Task 1-Student Profile
name = input("Enter your name:")
age = int(input("Enter your age:"))
percentage = float(input("Enter your percentage"))
print("Hello",name)
print("Your age is",age)
print("Your percentage is",percentage)
# Out:
# Enter your name: Abrar
# Enter your age: 24
# Enter your percentage 65.5
# Hello Abrar
# Your age is 24
# Your percentage is 65.5

# %%
# Task 2-Simple Calculator
x = int(input("Enter the number:"))
y = int(input("Enter the number:"))
total = x+y
difference = x-y
product = x*y
print("The sum of x and y:",total)
print("The difference between x and y:",difference)
print("The product of x and y:",product)
# Out:
# Enter the number: 72
# Enter the number: 64
# The sum of x and y: 136
# The difference between x and y: 8
# The product of x and y: 4608

# %%
#Task 3-Birth year calculator
name = input("Enter your name:")
year = int(input("Enter your birth year:"))
print("Welcome",name)
print("Your age is", 2026-year)
# Out:
# Enter your name: Abrar
# Enter your birth year: 2001
# Welcome Abrar
# Your age is 25

# %%
# Bonus Challenge
name = input("Name:")
age = int(input("Age:"))
height = float(input("Height:"))
weight = float(input("Weight:"))
print("Your Name is",name)
print("Your Age is",age)
print("Your Height is",height,"cm")
print("Your Weight is",weight,"kg")
# Out:
# Name: Abrar
# Age: 24
# Height: 175
# Weight: 100
# Your Name is Abrar
# Your Age is 24
# Your Height is 175.0 cm
# Your Weight is 100.0 kg

# %%
# Operators
a =10
b = 3
print("Addition:", a+b)
print("Subtraction:", a-b)
print("Multiplication:", a*b)
print("Division:", a/b)
print("Floor Division:", a//b)
print("Remainder:", a%b)
print("Power:", a**b)
# Out:
# Addition: 13
# Subtraction: 7
# Multiplication: 30
# Division: 3.3333333333333335
# Floor Division: 3
# Remainder: 1
# Power: 1000

# %%
x = 20
y = 15
print(x>y)
print(x<y)
print(x==y)
print(x!=y)
# Out:
# True
# False
# False
# True

# %%
x=10
x+=5
print(x)
x-=2
print(x)
x*=3
print(x)
# Out:
# 15
# 13
# 39

# %%
a=15
b=4
print("Addition:",a+b)
print("Subtraction:",a-b)
print("Multiplication:",a*b)
print("Division:",a/b)
print("Floor Division:",a//b)
print("Remainder:",a%b)
print("Power:",a**b)
print(a>b)
print(a<b)
print(a==b)
print(a!=b)
# Out:
# Addition: 19
# Subtraction: 11
# Multiplication: 60
# Division: 3.75
# Floor Division: 3
# Remainder: 3
# Power: 50625
# True
# False
# False
# True

# %%
# Task 1 – Basic Calculator
firstnumber = int(input("Enter the first number:"))
secondnumber = int(input("Enter the second number:"))
Addition = firstnumber + secondnumber
Subtraction = firstnumber - secondnumber
Multiplication = firstnumber * secondnumber
Division = firstnumber / secondnumber
floordivision = firstnumber // secondnumber
Remainder = firstnumber % secondnumber
Power = firstnumber ** secondnumber
print("Addition:",Addition)
print("Subtraction:",Subtraction)
print("Multiplication:",Multiplication)
print("Division:",Division)
print("Floor Division:",floordivision)
print("Remainder:",Remainder)
print("Power:",Power)
# Out:
# Enter the first number: 792
# Enter the second number: 24
# Addition: 816
# Subtraction: 768
# Multiplication: 19008
# Division: 33.0
# Floor Division: 33
# Remainder: 0
# Power: 3710260118471348482671264039117229101160442863712493489045519829303296

# %%
#Task 2 – Number Comparison
firstnumber = int(input("Enter the first number:"))
secondnumber = int(input("Enter the second number:"))

print("First number > Second number:",firstnumber > secondnumber)
print("First number < Second number:",firstnumber < secondnumber)
print("First number = Second number:",firstnumber == secondnumber)
print("First number != Second number:",firstnumber != secondnumber)
# Out:
# Enter the first number: 78
# Enter the second number: 94
# First number > Second number: False
# First number < Second number: True
# First number = Second number: False
# First number != Second number: True

# %%
# Task 3 – Age Eligibility
age = int(input("Enter your Age:"))
print(age >= 18 and age <= 60)
# Out:
# Enter your Age: 24
# True

# %%
#Bonus Challenge – Marks Checker
maths = int(input("Enter your Maths marks: "))
science = int(input("Enter your Science marks: "))

print("Passed both subjects:", maths >= 35 and science >= 35)
# Out:
# Enter your Maths marks:  79
# Enter your Science marks:  68
# Passed both subjects: True
